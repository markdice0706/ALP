# %%
#10^6

d_fa_limt_300 = [273522.0283633477, 311340.64945008385, 34481.2564647691, 11745.86117295608, 2592.4183066747883]
d_fa_limt_3000 = [864952.5998573563, 720460.8157860183, 34909.922851637646, 11760.784007399792, 2592.5967492697114]
d_s_fa_limt_300 = [273522.0283633477, 373920.54780734214, 73784.20968815913, 44257.26742162824, 20250.208625851184]
d_s_fa_limt_3000 = [864952.5998573563, 734711.1323937837, 131561.36461153376, 78769.07036380592, 36017.70257497266]
d_gaww_limt_300 = [2.9248101324302737e-05, 2.569532765519143e-05, 0.0002320101069453175, 0.0006810909717219687, 0.003085921735470748]
d_gaww_limt_3000 = [9.249061742018373e-06, 1.1104004304900399e-05, 0.0002291612053684248, 0.0006802267599648513, 0.0030857093384281447]
d_s_gaww_limt_300 = [2.9248101324302737e-05, 2.139491944722412e-05, 0.00010842428256413022, 0.00018076127303084355, 0.00039505765830912437]
d_s_gaww_limt_3000 = [9.249061742018373e-06, 1.088863316108328e-05, 6.080812572613475e-05, 0.00010156270682199099, 0.00022211300077642647]

m_axlist = [25, 20, 10, 5, 1]
d_x_seclist = [10890, 11850, 14060, 15250, 15990]


#10^5
c_fa_limt_300 = [273522.0283633477, 311340.64945008385, 364054.34521692304, 292136.5546412668, 2704.3139884353436]
c_fa_limt_3000 = [864952.5998573563, 720460.8157860183, 657709.6353659914, 476909.50134429894, 2704.516549482842]
c_s_fa_limt_300 = [273522.0283633477, 373920.54780734214, 367139.3139909612, 298864.65447669587, 20682.4281722308]
c_s_fa_limt_3000 = [864952.5998573563, 734711.1323937837, 695204.3853992937, 551866.5636104064, 36786.77886834739]
c_gaww_limt_300 = [2.9248101324302737e-05, 2.569532765519143e-05, 2.1974741148146913e-05, 2.7384453855231203e-05, 0.0029582363712982247]
c_gaww_limt_3000 = [9.249061742018373e-06, 1.1104004304900399e-05, 1.2163422230462372e-05, 1.6774671038110643e-05, 0.002958014807315474]
c_s_gaww_limt_300 = [2.9248101324302737e-05, 2.139491944722412e-05, 2.179009355613972e-05, 2.6767969648360692e-05, 0.0003868017784653146]
c_s_gaww_limt_3000 = [9.249061742018373e-06, 1.088863316108328e-05, 1.1507407271899133e-05, 1.4496257841139385e-05, 0.00021746943456589168]

d_x_seclist = [10890, 11850, 14060, 15250, 15990]

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(1)
plt.plot(m_axlist,d_fa_limt_300,color = 'green', linestyle='dashed')
plt.plot(m_axlist,d_s_fa_limt_300,label='10^6BG_Luminosity=300',color = 'green')
plt.plot(m_axlist,d_fa_limt_3000,color = 'gold', linestyle='dashed')
plt.plot(m_axlist,d_s_fa_limt_3000,label='10^6BG_Luminosity=3000',color = 'gold')

plt.plot(m_axlist,c_fa_limt_300,color = 'orange', linestyle='dashed')
plt.plot(m_axlist,c_s_fa_limt_300,label='10^5BG_Luminosity=300',color = 'orange')
plt.plot(m_axlist,c_fa_limt_3000,color = 'blue', linestyle='dashed')
plt.plot(m_axlist,c_s_fa_limt_3000,label='10^5BG_Luminosity=3000',color = 'blue')

plt.title('fa limit')
plt.xlabel('ALP mass')
plt.ylabel('fa')
plt.yscale("log")
plt.legend(loc='best')
plt.show



plt.figure(2)
plt.plot(m_axlist,d_gaww_limt_300,color = 'green', linestyle='dashed')
plt.plot(m_axlist,d_s_gaww_limt_300,label='10^6BG_Luminosity=300',color = 'green')
plt.plot(m_axlist,d_gaww_limt_3000,color = 'gold', linestyle='dashed')
plt.plot(m_axlist,d_s_gaww_limt_3000,label='10^6BG_Luminosity=3000',color = 'gold')

plt.plot(m_axlist,c_gaww_limt_300,color = 'orange', linestyle='dashed')
plt.plot(m_axlist,c_s_gaww_limt_300,label='10^5BG_Luminosity=300',color = 'orange')
plt.plot(m_axlist,c_gaww_limt_3000,color = 'blue', linestyle='dashed')
plt.plot(m_axlist,c_s_gaww_limt_3000,label='10^5BG_Luminosity=3000',color = 'blue')
plt.title('gaww limit')
plt.xlabel('ALP mass')
plt.ylabel('gaww')
plt.yscale("log")
plt.legend(loc='best')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
w_mass_small= [25, 20, 10, 5, 1]
g_aww_300_small = [2.9248101324302737e-05, 2.139491944722412e-05, 0.00010842428256413022, 0.00018076127303084355, 0.00039505765830912437]
error_g_aww_300_small = [2.9248101324302737e-05, 2.569532765519143e-05, 0.0002320101069453175, 0.0006810909717219687, 0.003085921735470748]
g_aww_3k_small = [9.249061742018373e-06, 1.088863316108328e-05, 6.080812572613475e-05, 0.00010156270682199099, 0.00022211300077642647]
error_g_aww_3k_small = [9.249061742018373e-06, 1.1104004304900399e-05, 0.0002291612053684248, 0.0006802267599648513, 0.0030857093384281447]


plt.figure(2)
plt.plot(w_mass_small,error_g_aww_300_small,color = 'green', linestyle='dashed')
plt.plot(w_mass_small,g_aww_300_small,label='10^6BG_Luminosity=300',color = 'green')
plt.plot(w_mass_small,error_g_aww_3k_small,color = 'gold', linestyle='dashed')
plt.plot(w_mass_small,g_aww_3k_small,label='10^6BG_Luminosity=3000',color = 'gold')

plt.plot(m_axlist,c_gaww_limt_300,color = 'orange', linestyle='dashed')
plt.plot(m_axlist,c_s_gaww_limt_300,label='10^5BG_Luminosity=300',color = 'orange')
plt.plot(m_axlist,c_gaww_limt_3000,color = 'blue', linestyle='dashed')
plt.plot(m_axlist,c_s_gaww_limt_3000,label='10^5BG_Luminosity=3000',color = 'blue')
plt.title('gaww limit')
plt.xlabel('ALP mass')
plt.ylabel('gaww')
plt.yscale("log")
plt.legend(loc='best')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
